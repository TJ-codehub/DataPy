# %% [markdown]
# # Data Visualization
#
# ## DataPy - Week 8
#
# ### Data Science Practical Python

# %% [markdown]
# # Review & Context
#
# ## Previous Topics
#
# - ✓ Python Fundamentals (Week 1-3)
# - ✓ NumPy & Arrays (Week 4)
# - ✓ Pandas & DataFrames (Week 5)
# - ✓ Data Cleaning & Transformation (Week 7)
#
# ## Today
#
# **Overall Goal: Visualizing data for the semester project**

# %% [markdown]
# # Why Data Visualization?
#
# ## A Picture is Worth 1000 Numbers
#
# | Advantages | Examples |
# |----------|----------|
# | Quick understanding | Recognize patterns & trends |
# | Discover outliers | Identify anomalies |
# | Communication | Present results |
# | Decision making | Data-driven insights |
#
# ---
#
# > *"The greatest value of a picture is when it forces us to notice what we never expected to see."* - John Tukey

# %% [markdown]
# # Visualization Types Overview
#
# ## Which Chart for What?
#
# | Goal | Suitable Plots |
# |------|----------------|
# | **Comparison** | Bar chart, Line chart |
# | **Distribution** | Histogram, Boxplot, Violin Plot |
# | **Relationship** | Scatterplot, Heatmap |
# | **Composition** | Pie chart, Stacked Bar |
# | **Time series** | Line chart, Area Chart |
#
# **Important:** Choose visualization appropriate to the question!

# %% [markdown]
# # Python Visualization Libraries
#
# ## Three Main Libraries
#
# ### 1. Matplotlib
# - Foundation of Python visualization
# - Maximum flexibility & control
# - Most widely used
#
# ### 2. Seaborn
# - Built on Matplotlib
# - Beautiful statistical plots
# - Less code needed
#
# ### 3. Plotly
# - Interactive visualizations
# - Modern & web-ready
# - Hover effects & zoom

# %% [markdown]
# # 1. Matplotlib: The Foundation
#
# ## Basic Structure
# <img src="figures/myFirstPlot.png" style="float: right; width: 40%; margin-right: 50px;">
#
#
# ```python
# import matplotlib.pyplot as plt
# import numpy as np #to generate data
#
# # Create figure and axis
# fig, ax = plt.subplots(figsize=(10, 6))
#
# # Generate random data
# x = np.sort(np.random.randint(0, 101, size=20))
# y = np.random.randint(0, 11, size=20)
# ax.plot(x, y, marker='*')
#
# # Plot data
# ax.plot(x, y)
#
# # Labels & title
# ax.set_xlabel('X-Axis')
# ax.set_ylabel('Y-Axis')
# ax.set_title('My First Plot')
#
# # save and show plot
# plt.savefig('myFirstPlot.png', dpi=150, bbox_inches='tight')
# plt.show()
# ```

# %% [markdown]
# # The Most Important Plot Types
#
# <img src="figures/line chart.png" style="float: right; width: 40%; margin-right: 50px;">
#
# ## (1) Line Plot
# - Time series, trends over time
# - Continuous data

# %% [markdown]
# # The Most Important Plot Types
#
# <img src="figures/barChart_vs_histogram.png" style="float: right; width: 40%; margin-right: 50px;">
#
# ## (2) Bar Chart
# - Comparison of categories
# - Discrete data
#
# ## (3) Histogram
# - Distribution of numerical data
# - Frequencies

# %% [markdown]
# # The Most Important Plot Types
#
# <img src="figures/boxplotMit3Gruppen.png" style="float: right; width: 30%;margin-right: 150px">
#
#
# ## (4) Boxplot
# - Show distribution
# - Median, quartiles, outliers

# %% [markdown]
# # The Most Important Plot Types
#
# <img src="figures/map_overview.png" style="float: right; width: 70%; margin-right: 50px;">
#
# ## (5) Scatterplot
# - Relationship between two variables
# - Recognize correlations

# %% [markdown]
# # Matplotlib: Subplots
#
# ## Multiple Plots Side by Side

# %%
import matplotlib.pyplot as plt
import numpy as np

# Random data
x          = np.linspace(0, 100, 50)
y1         = np.random.randint(0, 101, size=50)
y2         = np.random.uniform(0, 100, size=50)
categories = ['A', 'B', 'C', 'D', 'E']
values     = np.random.randint(0, 101, size=5)
data       = np.random.normal(loc=50, scale=15, size=500)

# 2 rows, 2 columns
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# First plot (top left)
axes[0, 0].plot(x, y1)
axes[0, 0].set_title('Plot 1 - line')

# Second plot (top right)
axes[0, 1].scatter(x, y2)
axes[0, 1].set_title('Plot 2 - scatter')

# Third plot (bottom left)
axes[1, 0].bar(categories, values)
axes[1, 0].set_title('Plot 3 - bar')

# Fourth plot (bottom right)
axes[1, 1].hist(data, bins=20)
axes[1, 1].set_title('Plot 4 - histogram')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 2. Seaborn: Statistical Plots
#
# ## Elegant & Simple

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Random DataFrame df
np.random.seed(42)
n = 200
df = pd.DataFrame({
    'age':      np.random.randint(18, 80, size=n),
    'category': np.random.choice(['A', 'B', 'C'], size=n),
    'value':    np.random.normal(loc=50, scale=15, size=n),
    'score':    np.random.uniform(0, 100, size=n),
    'income':   np.random.normal(loc=3000, scale=800, size=n)
})

# Set style
sns.set_style('whitegrid')

# Histogram with KDE
fig, ax = plt.subplots(figsize=(10, 6))
sns.histplot(data=df, x='age', kde=True, ax=ax)
plt.tight_layout()
plt.show()

# Boxplot by category
fig, ax = plt.subplots(figsize=(10, 6))
sns.boxplot(data=df, x='category', y='value', ax=ax)
plt.tight_layout()
plt.show()

# Violin plot: combi --> Boxplot + KDE
fig, ax = plt.subplots(figsize=(10, 6))
sns.violinplot(data=df, x='category', y='value', ax=ax)
plt.tight_layout()
plt.show()

# Correlation heatmap (nur numerische Spalten)
fig, ax = plt.subplots(figsize=(8, 6))
sns.heatmap(df.select_dtypes(include='number').corr(), annot=True, cmap='coolwarm', ax=ax)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Seaborn: Pairplot
#
# ## All Relationships at a Glance
#
# ```python
# # Automatic pairwise plots of all numerical columns
# sns.pairplot(df, hue='target_column')
# plt.show()
# ```
#
# **Perfect for:**
# - Exploratory Data Analysis (EDA)
# - Quickly recognize correlations
# - Identify outliers

# %%
# Automatic pairwise plots of all numerical columns
sns.pairplot(df, hue='category')
plt.show()

# %% [markdown]
# # 3. Plotly: Interactive Visualizations
#
# ## Zoom, Hover & More
#
# ```python
# import plotly.express as px
#
# # Interactive line plot
# fig = px.line(df, x='date', y='value', title='Time Series')
# fig.show()
#
# # Interactive scatter with color
# fig = px.scatter(df, x='x', y='y', color='category',
#                  hover_data=['info'])
# fig.show()
#
# # Interactive boxplot
# fig = px.box(df, x='category', y='value')
# fig.show()
# ```
#
# **Advantage:** Explore data interactively!

# %%
import plotly.express as px
import pandas as pd
import numpy as np

# Random DataFrame erstellen
np.random.seed(42)
n = 100
df = pd.DataFrame({
    'date':     pd.date_range(start='2024-01-01', periods=n, freq='D'),
    'value':    np.random.randint(0, 101, size=n),
    'x':        np.random.uniform(0, 100, size=n),
    'y':        np.random.uniform(0, 100, size=n),
    'category': np.random.choice(['A', 'B', 'C'], size=n),
    'info':     [f'Punkt {i}' for i in range(n)]
})



# Interactive line plot
fig = px.line(df, x='date', y='value', title='Time Series')
fig.show()

# Interactive scatter with color
fig = px.scatter(df, x='x', y='y', color='category',
                 hover_data=['info'])
fig.show()

# Interactive boxplot
fig = px.box(df, x='category', y='value')
fig.show()

# %% [markdown]
# # Relation to Semester Project
#
# ## Use Week 7 Cleaned Data
#
# **Goal Today:**
# - Create visualizations for your project
# - Recognize patterns in data
# - Identify relationships between variables
#
# ## Typical Analyses
# 1. **Distribution:** How is data distributed?
# 2. **Correlations:** Which features are related?
# 3. **Outliers:** Are there unusual values?
# 4. **Groups:** Are there differences between groups?

# %% [markdown]
# # Visualization Best Practices
#
# ## Do's
# ✓ Always label axes
# ✓ Add title
# ✓ Choose appropriate colors
# ✓ Save figures (PNG, PDF)
#
# ## Don'ts
# ✗ Too many colors
# ✗ 3D charts (hard to read)
# ✗ Too much information in one plot
# ✗ Misleading axes (not starting at 0)

# %% [markdown]
# # Saving Figures
#
# ## For Documentation & Presentation
#
# ```python
# # Matplotlib/Seaborn
# plt.savefig('my_plot.png', dpi=300, bbox_inches='tight')
# plt.savefig('my_plot.pdf')  # For LaTeX
#
# # Plotly
# fig.write_image('my_plot.png')
# fig.write_html('my_plot.html')  # Interactive!
# ```
#
# **Tip:** Create a `figures/` folder for your project

# %% [markdown]
# # Tasks for Today
#
# ## Exercise Notebooks
#
# **Work on your project data (cleaned from Week 7):**
#
# 1. **Matplotlib**: Create basic plots (Histogram, Scatterplot, Subplots)
# 2. **Seaborn**: Statistical plots (Boxplot, Violin, Heatmap)
# 3. **Plotly**: Create interactive visualizations
# 4. **Project relation**: Consider which plots make sense for your project
#
# ---
#
# **Exercise in Jupyter Notebook:** `8_DataVisualization_exercise.ipynb`

# %% [markdown]
# # Useful Resources
#
# ## 📚 Documentation
# - Matplotlib: matplotlib.org
# - Seaborn: seaborn.pydata.org
# - Plotly: plotly.com/python
#
# ## 🎨 Inspiration
# - Python Graph Gallery: python-graph-gallery.com
# - Seaborn Gallery: seaborn.pydata.org/examples
#
# ## 🎯 Tutorials
# - Kaggle Learn: Visualization Course
# - Real Python: Python Plotting Guides
